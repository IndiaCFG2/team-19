# %%
from nltk.corpus import twitter_samples

# %%
# loading data

positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
neutral = twitter_samples.strings('tweets.20150430-223406.json')

tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
# Lemmatization

from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

# %%
# Cleaning

import re, string

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
# Stop words and tokenization

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

print(remove_noise(tweet_tokens[0], stop_words))

positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')
neutral_tweet_tokens = twitter_samples.tokenized('tweets.20150430-223406.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []
neutral_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))
    
for tokens in neutral_tweet_tokens:
    neutral_cleaned_tokens_list.append(remove_noise(tokens, stop_words))
# Out:
# ['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)']

# %%
from nltk import FreqDist

freq_dist_pos = FreqDist(all_pos_words)
print(freq_dist_pos.most_common(10))
# Out:
# []

# %%
# Extracting tokens

def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)
neutral_tokens_for_model = get_tweets_for_model(neutral_cleaned_tokens_list)

# %%
# test train partition

import random

positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

neutral_dataset = [(tweet_dict, "Neutral")
                     for tweet_dict in neutral_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:8000]
test_data = dataset[8000:]

# %%
dataset
# Out:
# [({':(': True,
#    'betis': True,
#    'close': True,
#    'greatings': True,
#    'hello': True,
#    'info': True,
#    'interest': True,
#    'join': True,
#    'jonathas': True,
#    'possible': True},
#   'Negative'),
#  ({':(': True,
#    'anything': True,
#    "can't": True,
#    'even': True,
#    'pay': True,
#    'play': True,
#    'properly': True,
#    'solution': True,
#    'website': True},
#   'Negative'),
#  ({':(': True,
#    'aigooo': True,
#    'cant': True,
#    'get': True,
#    'riri': True,
#    'seungchan': True},
#   'Negative'),
#  ({'...': True, ':(': True, 'yeah': True}, 'Negative'),
#  ({'2ne1': True, ':d': True, 'beautiful': True, 'day': True, 'good': True},
#   'Positive'),
#  ({'...': True,
#    ':)': True,
#    'attack': True,
#    'attentive': True,
#    'criticise': True,
#    'every': True,
#    'gesture': True,
#    'little': True,
#    'must': True,
#    'notice': True,
#    'one': True,
#    'pedal': True,
#    'stroke': True,
#    'thing': True,
#    'word': True,
#    '´': True},
#   'Positive'),
#  ({':-(': True,
#    'ask': True,
#    'bos': True,
#    'climb': True,
#    'hand': True,
#    'ladder': True,
#    'raise': True,
#    'success': True,
#    'tell': True},
#   'Negative'),
#  ({':d': True, 'anime': True, 'funny': True, 'next': True, 'umaru': True},
#   'Positive'),
#  ({'#summerismissing': True,
#    '#whereisthesun': True,
#    ':(': True,
#    'feels': True,
#    'like': True,
#    'winter': True},
#   'Negative'),
#  ({':(': True, 'go': True, 'vidcon': True, 'wish': True}, 'Negative'),
#  ({':)': True,
#    'like': True,
#    'love': True,
#    'tattoo': True,
#    'thank': True,
#    'ur': True,
#    'wow': True,
#    '—': True},
#   'Positive'),
#  ({':)': True, 'excited': True, 'picts': True, 'second': True}, 'Positive'),
#  ({':(': True, 'explain': True, 'miss': True, 'way': True, 'word': True},
#   'Negative'),
#  ({':(': True, 'snake': True}, 'Negative'),
#  ({'2weeks': True, ':)': True, 'bruuh': True, 'chill': True, 'count': True},
#   'Positive'),
#  ({':)': True, 'promise': True, 'soon': True}, 'Positive'),
#  ({':(': True, 'anyway': True, 'bother': True, 'cold': True, 'never': True},
#   'Negative'),
#  ({':(': True,
#    'almost': True,
#    'go': True,
#    'need': True,
#    'school': True,
#    'shopping': True,
#    'start': True,
#    'week': True},
#   'Negative'),
#  ({':(': True, 'computer': True, 'mine': True, 'ur': True}, 'Negative'),
#  ({':d': True, 'amazing': True, 'deserve': True, 'siddi': True}, 'Positive'),
#  ({':(': True, 'today': True, 'want': True, 'win': True}, 'Negative'),
#  ({':p': True, 'link': True, 'plz': True}, 'Positive'),
#  ({':)': True,
#    'act': True,
#    'around': True,
#    'feel': True,
#    'know': True,
#    'mean': True},
#   'Positive'),
#  ({'1': True,
#    ':d': True,
#    'b2b': True,
#    'b2c': True,
#    'benefit': True,
#    'department': True,
#    'different': True,
#    "else's": True,
#    'enterprison': True,
#    'funny': True,
#    'idea': True,
#    'money': True,
#    'someone': True,
#    'soo': True,
#    "that's": True,
#    'v': True},
#   'Positive'),
#  ({'2emt': True, ':)': True, 'monday': True, 'see': True}, 'Positive'),
#  ({'318': True,
#    ':(': True,
#    'beli̇eve': True,
#    'follow': True,
#    'justi̇n': True,
#    'love': True,
#    'much': True,
#    'please': True,
#    'wi̇ll': True,
#    'x15': True,
#    '♛': True,
#    '》': True,
#    'ｍｅ': True,
#    'ｓｅｅ': True},
#   'Negative'),
#  ({':(': True,
#    'back': True,
#    'come': True,
#    'please': True,
#    'wwe': True,
#    'تكفى': True},
#   'Negative'),
#  ({':-(': True, 'dear': True, 'oh': True, 'xx': True}, 'Negative'),
#  ({'#pglcsgo': True,
#    ':)': True,
#    'birthday': True,
#    'forget': True,
#    'happy': True,
#    'never': True},
#   'Positive'),
#  ({':)': True,
#    'andrew': True,
#    'day': True,
#    'great': True,
#    'right': True,
#    'thx': True},
#   'Positive'),
#  ({':(': True, 'evil': True, 'pepper': True, 'system': True}, 'Negative'),
#  ({':-(': True, 'mefd': True, 'notice': True, 'please': True}, 'Negative'),
#  ({':(': True,
#    'deserve': True,
#    'high': True,
#    'molly': True,
#    'much': True,
#    'place': True},
#   'Negative'),
#  ({'...': True,
#    ':)': True,
#    'allow': True,
#    'consistency': True,
#    'free': True,
#    'good': True,
#    'idea': True,
#    'speculation': True,
#    'stress': True,
#    'work': True},
#   'Positive'),
#  ({'4': True, ':)': True, 'every': True, 'year': True}, 'Positive'),
#  ({'3am': True, ':(': True, "can't": True, 'sleep': True}, 'Negative'),
#  ({'2': True,
#    ':)': True,
#    'ily': True,
#    'stephanie': True,
#    'thank': True,
#    '💖': True},
#   'Positive'),
#  ({':)': True, 'ahh': True, 'much': True, 'thank': True, 'xxx': True},
#   'Positive'),
#  ({':(': True, 'splendour': True}, 'Negative'),
#  ({':-)': True, 'anyway': True, 'would': True}, 'Positive'),
#  ({'...': True,
#    '1': True,
#    ':)': True,
#    'every': True,
#    'ian': True,
#    'jamie': True,
#    'night': True,
#    'post': True,
#    'thanks': True,
#    'usually': True},
#   'Positive'),
#  ({':)': True,
#    'everyday': True,
#    'follow': True,
#    'good': True,
#    'im': True,
#    'inspire': True,
#    'life': True,
#    'like': True,
#    'love': True,
#    'mind': True,
#    'someone': True,
#    'thankful': True},
#   'Positive'),
#  ({':)': True,
#    'change': True,
#    'design': True,
#    'final': True,
#    'hope': True,
#    'like': True,
#    'make': True},
#   'Positive'),
#  ({'#choiceinternationalartist': True,
#    '#superjunior': True,
#    '#teenchoice': True,
#    ':)': True,
#    'love': True},
#   'Positive'),
#  ({':)': True,
#    'account': True,
#    'best': True,
#    'decide': True,
#    'ever': True,
#    'log': True,
#    'moment': True,
#    'onto': True,
#    'saw': True,
#    'thing': True,
#    'year': True},
#   'Positive'),
#  ({':(': True,
#    'doggy': True,
#    'get': True,
#    "i've": True,
#    'one': True,
#    'poorly': True},
#   'Negative'),
#  ({':(': True,
#    'beta': True,
#    'close': True,
#    'end': True,
#    'finishing': True,
#    'monday': True,
#    'sadly': True,
#    'year': True},
#   'Negative'),
#  ({':(': True,
#    "can't": True,
#    'despair': True,
#    'hope': True,
#    'let': True,
#    'live': True,
#    'ok': True,
#    'people': True,
#    'shocking': True,
#    'sometimes': True,
#    "that's": True,
#    'world': True},
#   'Negative'),
#  ({':)': True, 'family': True, 'welcome': True}, 'Positive'),
#  ({':)': True,
#    'day': True,
#    'fav': True,
#    'make': True,
#    'tweet': True,
#    'woke': True,
#    'yo': True,
#    '😂': True},
#   'Positive'),
#  ({':(': True, 'dont': True, 'paypal': True, 'want': True}, 'Negative'),
#  ({':(': True,
#    'game': True,
#    'good': True,
#    "i'm": True,
#    'late': True,
#    'miss': True,
#    'show': True,
#    "they'd": True},
#   'Negative'),
#  ({'#더쇼': True,
#    '#에이핑크': True,
#    ':(': True,
#    'apink': True,
#    'want': True,
#    'win': True},
#   'Negative'),
#  ({':-(': True,
#    "can't": True,
#    'feel': True,
#    'melon': True,
#    'really': True,
#    'stream': True,
#    'useless': True},
#   'Negative'),
#  ({':(': True,
#    'happy': True,
#    'horribly': True,
#    'im': True,
#    'treat': True,
#    'u': True,
#    'ugh': True,
#    'v': True},
#   'Negative'),
#  ({':p': True, 'take': True, 'u': True, 'write': True}, 'Positive'),
#  ({':)': True, 'back': True, 'front': True, 'squat': True, 'usually': True},
#   'Positive'),
#  ({'10': True, ':d': True, 'half': True, 'start': True}, 'Positive'),
#  ({':(': True, 'colour': True, 'hair': True, 'miss': True}, 'Negative'),
#  ({':p': True,
#    'august': True,
#    'dunno': True,
#    'every': True,
#    'fever': True,
#    'get': True,
#    'year': True,
#    '😷': True},
#   'Positive'),
#  ({':(': True, 'hug': True, 'want': True, 'watch': True}, 'Negative'),
#  ({':-)': True,
#    'excite': True,
#    "i'm": True,
#    'picnic': True,
#    'really': True,
#    'tmrw': True},
#   'Positive'),
#  ({':(': True,
#    'computer': True,
#    'ipod': True,
#    'livestream': True,
#    'load': True,
#    'want': True,
#    'watch': True},
#   'Negative'),
#  ({':(': True, 'hua': True, 'kuch': True, 'nahi': True, 'root': True},
#   'Negative'),
#  ({':)': True,
#    'dad': True,
#    'hill': True,
#    'hock': True,
#    'mamma': True,
#    'monday': True,
#    'picnic': True,
#    'race': True,
#    'ready': True,
#    'saturday': True,
#    'sunday': True,
#    'track': True,
#    'weekend': True,
#    'work': True},
#   'Positive'),
#  ({':(': True, 'box': True, 'pengen': True, '—': True}, 'Negative'),
#  ({'...': True,
#    ':-)': True,
#    'good': True,
#    'kinda': True,
#    'morning': True,
#    'smoke': True,
#    'tip': True,
#    'wish': True},
#   'Positive'),
#  ({':(': True, 'like': True, 'misspell': True, 'omg': True, 'saw': True},
#   'Negative'),
#  ({':-)': True, 'fucked': True, "i'm": True, 'kinda': True, 'sort': True},
#   'Positive'),
#  ({':)': True,
#    'beatport': True,
#    'collection': True,
#    'find': True,
#    'hoping': True,
#    'soon': True,
#    'spotify': True,
#    'team': True,
#    'via': True},
#   'Positive'),
#  ({':(': True,
#    'literally': True,
#    'paper': True,
#    'time': True,
#    'town': True,
#    'watch': True},
#   'Negative'),
#  ({':d': True, 'among': True, 'fav': True, 'time': True, 'tweet': True},
#   'Positive'),
#  ({':(': True, 'chance': True, 'last': True}, 'Negative'),
#  ({'>:(': True,
#    'bin': True,
#    'chrome': True,
#    'get': True,
#    'osx': True,
#    'voiceover': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'kak': True,
#    'right': True,
#    'sinuend': True,
#    'work': True},
#   'Negative'),
#  ({'#dota2': True,
#    ':)': True,
#    'awesome': True,
#    'dieback': True,
#    'music': True,
#    'pack': True,
#    'totally': True,
#    'worth': True},
#   'Positive'),
#  ({'#hotgirls': True,
#    '#like4like': True,
#    '#porn': True,
#    '#repost': True,
#    '#skype': True,
#    '#snapchat': True,
#    '#snapchatme': True,
#    '19': True,
#    ':(': True,
#    'lisaherring': True,
#    'snapchat': True},
#   'Negative'),
#  ({':)': True,
#    'aboard': True,
#    'graze': True,
#    'great': True,
#    'lani': True,
#    'us': True,
#    'welcome': True,
#    'woohoo': True},
#   'Positive'),
#  ({'#cjradacomateada': True, ':)': True, 'thanks': True}, 'Positive'),
#  ({':(': True, 'dd': True, 'lagi': True, 'leave': True}, 'Negative'),
#  ({':)': True,
#    'give': True,
#    "i'll": True,
#    'look': True,
#    'minute': True,
#    'take': True},
#   'Positive'),
#  ({':(': True,
#    'barcelona': True,
#    'beet': True,
#    'dad': True,
#    'either': True,
#    'food': True,
#    'home': True,
#    'juice': True,
#    'kitchen': True,
#    'money': True,
#    'month': True,
#    'thanks': True,
#    'wallet': True},
#   'Negative'),
#  ({'..': True,
#    ':)': True,
#    'charity': True,
#    'hope': True,
#    'keep': True,
#    'lose': True,
#    'perhaps': True,
#    'renew': True,
#    'smile': True,
#    'smiling': True,
#    'someone': True,
#    "who's": True,
#    '•': True},
#   'Positive'),
#  ({':(': True, 'exit': True, 'gomen': True}, 'Negative'),
#  ({':d': True, 'haha': True, 'well': True}, 'Positive'),
#  ({'50.000': True,
#    '8': True,
#    ':d': True,
#    'ball': True,
#    'coins': True,
#    'free': True,
#    'heiyo': True,
#    'pool': True,
#    'thanks': True,
#    'visit': True,
#    'website': True,
#    'العنزي': True,
#    'بندر': True},
#   'Positive'),
#  ({':-(': True,
#    'day': True,
#    'get': True,
#    'knee': True,
#    'ouch': True,
#    'replacement': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'always': True,
#    'hive': True,
#    'shit': True,
#    'suck': True,
#    'vote': True,
#    'yes': True},
#   'Negative'),
#  ({':)': True, 'evet': True}, 'Positive'),
#  ({':(': True, 'already': True, 'miss': True}, 'Negative'),
#  ({':)': True, 'sc': True}, 'Positive'),
#  ({':)': True,
#    'ball': True,
#    'excite': True,
#    'falklands': True,
#    'friday': True,
#    'happy': True,
#    'plan': True,
#    'weekend': True,
#    'winter': True},
#   'Positive'),
#  ({':(': True, 'app': True}, 'Negative'),
#  ({':)': True,
#    'abit': True,
#    'around': True,
#    'barnstaple': True,
#    'bideford': True,
#    'day': True,
#    'hey': True,
#    'know': True,
#    'liam': True,
#    'planning': True,
#    'road': True,
#    "spot's": True,
#    'stay': True,
#    'sweet': True,
#    'trip': True},
#   'Positive'),
#  ({':)': True,
#    'affect': True,
#    'clear': True,
#    "i'll": True,
#    'make': True,
#    'theory': True,
#    'tomorrow': True,
#    'update': True,
#    'vid': True},
#   'Positive'),
#  ({':(': True, 'feel': True, 'good': True}, 'Negative'),
#  ({':(': True,
#    'cage': True,
#    'pain': True,
#    'rib': True,
#    'right': True,
#    'since': True,
#    'yesterday': True},
#   'Negative'),
#  ({':)': True,
#    'gas': True,
#    'get': True,
#    'legit': True,
#    'loser': True,
#    'sit': True},
#   'Positive'),
#  ({'#tierd': True,
#    ':(': True,
#    'emotionally': True,
#    'mentally': True,
#    'physically': True},
#   'Negative'),
#  ({':)': True,
#    'aling': True,
#    'especially': True,
#    'lass': True,
#    'three': True,
#    'w': True},
#   'Positive'),
#  ({':(': True, 'sorry': True, 'sure': True, 'x': True}, 'Negative'),
#  ({':(': True,
#    'ahaha': True,
#    'bed': True,
#    'glass': True,
#    "i'm": True,
#    'lay': True,
#    'like': True,
#    'pretty': True,
#    'suck': True,
#    'whyyyyyy': True,
#    'wine': True},
#   'Negative'),
#  ({'...': True,
#    ':-)': True,
#    'currently': True,
#    'day': True,
#    'friday': True,
#    'good': True,
#    'morning': True,
#    'plan': True,
#    'play': True,
#    'shop': True,
#    '\U000fec00': True},
#   'Positive'),
#  ({':)': True, "f'ing": True, 'sure': True}, 'Positive'),
#  ({'..': True,
#    '1pm': True,
#    ':(': True,
#    'holiday': True,
#    "i'm": True,
#    'nat': True,
#    'school': True,
#    'sorry': True,
#    'work': True},
#   'Negative'),
#  ({':)': True, 'life': True, 'need': True}, 'Positive'),
#  ({':)': True,
#    '<3': True,
#    'bam': True,
#    'bestfriend': True,
#    'follow': True,
#    'hi': True,
#    'lot': True,
#    'love': True,
#    'see': True,
#    'warsaw': True,
#    'x21': True},
#   'Positive'),
#  ({'david': True, 'fun': True, 'probs': True, 'u': True}, 'Negative'),
#  ({':-(': True,
#    'awake': True,
#    "i've": True,
#    'like': True,
#    'since': True,
#    'three': True},
#   'Negative'),
#  ({'6th': True,
#    ':(': True,
#    'august': True,
#    'clothes': True,
#    'dont': True,
#    'get': True,
#    'hella': True,
#    'lol': True,
#    'pay': True,
#    'still': True,
#    'though': True,
#    'til': True,
#    'yasss': True},
#   'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'u': True}, 'Positive'),
#  ({':)': True,
#    'enjoy': True,
#    'hope': True,
#    "i'm": True,
#    'know': True,
#    'let': True,
#    'proud': True,
#    'view': True,
#    'work': True},
#   'Positive'),
#  ({':(': True, 'cuddle': True, 'pilllow': True, 'wanna': True}, 'Negative'),
#  ({':-)': True,
#    'enjoy': True,
#    'glad': True,
#    'much': True,
#    'thank': True,
#    'us': True,
#    "we're": True},
#   'Positive'),
#  ({':-(': True,
#    "can't": True,
#    'cornettos': True,
#    'figure': True,
#    'free': True,
#    'get': True,
#    'x': True},
#   'Negative'),
#  ({':)': True,
#    'appreciate': True,
#    'follow': True,
#    'hi': True,
#    'jawad': True,
#    'much': True,
#    'retweet': True,
#    'thank': True,
#    'today': True},
#   'Positive'),
#  ({':(': True, 'malik': True, 'please': True, 'zayn': True}, 'Negative'),
#  ({':)': True, 'fback': True}, 'Positive'),
#  ({'..': True,
#    ':)': True,
#    'best': True,
#    'donna': True,
#    'great': True,
#    'hi': True,
#    'kina': True,
#    'love': True,
#    'see': True,
#    'tonight': True},
#   'Positive'),
#  ({'...': True,
#    ':-)': True,
#    'another': True,
#    'favourite': True,
#    'good': True,
#    'hole': True,
#    'luck': True,
#    'potential': True,
#    'water': True},
#   'Positive'),
#  ({'#cc': True,
#    '#climatechange': True,
#    '#tcot': True,
#    '#uniteblue': True,
#    '...': True,
#    ':-(': True,
#    'air': True,
#    'califor': True,
#    "california's": True,
#    'influential': True,
#    'pollution': True,
#    'powerful': True,
#    'watchdog': True},
#   'Negative'),
#  ({'#ceo1month': True,
#    '#kunoriforceo': True,
#    ':)': True,
#    'finish': True,
#    'presentation': True,
#    'thank': True},
#   'Positive'),
#  ({':)': True,
#    'approve': True,
#    'bailona': True,
#    'fanbase': True,
#    'one': True,
#    'recognize': True},
#   'Positive'),
#  ({'50': True,
#    ':)': True,
#    'bnf': True,
#    'good': True,
#    'point': True,
#    'system': True,
#    'trade': True},
#   'Positive'),
#  ({':(': True, 'alone': True, 'leave': True}, 'Negative'),
#  ({':(': True, 'chocolate': True, 'damn': True, 'forget': True, 'hot': True},
#   'Negative'),
#  ({':)': True}, 'Positive'),
#  ({':)': True,
#    'always': True,
#    'amaze': True,
#    'drink': True,
#    'forget': True,
#    'people': True,
#    'water': True},
#   'Positive'),
#  ({':(': True, 'die': True, 'painful': True, 'way': True}, 'Negative'),
#  ({':(': True, 'grepe': True, 'grepein': True}, 'Negative'),
#  ({'..': True,
#    ':)': True,
#    'hahahaaah': True,
#    'knock': True,
#    'momma': True,
#    'owly': True,
#    'say': True},
#   'Positive'),
#  ({':(': True, 'find': True, 'ummm': True}, 'Negative'),
#  ({':-)': True,
#    'careful': True,
#    'favourite': True,
#    "i'll": True,
#    'late': True,
#    'like': True,
#    'look': True,
#    'much': True,
#    'need': True,
#    'one': True,
#    'study': True},
#   'Positive'),
#  ({':p': True, "it'll": True, 'least': True, 'refresh': True, 'well': True},
#   'Positive'),
#  ({':)': True, 'cool': True}, 'Positive'),
#  ({':)': True, "i'm": True, 'talk': True, 'want': True}, 'Positive'),
#  ({'2': True,
#    ':)': True,
#    'hot': True,
#    'know': True,
#    'let': True,
#    'make': True,
#    'music': True,
#    'pwrfl': True,
#    'sense': True,
#    'superpower': True,
#    'u': True,
#    'video': True,
#    'want': True},
#   'Positive'),
#  ({':)': True, 'happy': True, "i've": True, 'lately': True}, 'Positive'),
#  ({'..': True, ':(': True, 'avi': True, 'dude': True, 'need': True},
#   'Negative'),
#  ({':-)': True,
#    'ago': True,
#    'kinda': True,
#    'know': True,
#    'marrickville': True,
#    'public': True,
#    'smug': True,
#    'stuff': True,
#    'ten': True,
#    'year': True},
#   'Positive'),
#  ({':)': True, 'day': True, 'follow': True, 'great': True, 'thanks': True},
#   'Positive'),
#  ({':)': True,
#    'address': True,
#    'anytime': True,
#    'hahaha': True,
#    'oh': True,
#    'send': True,
#    'taste': True,
#    'tell': True,
#    'wanna': True,
#    'yer': True},
#   'Positive'),
#  ({':(': True,
#    'circuit': True,
#    'day': True,
#    'miss': True,
#    'school': True,
#    'secondary': True,
#    'training': True},
#   'Negative'),
#  ({':(': True, 'agree': True, 'completely': True, 'press': True}, 'Negative'),
#  ({':(': True, 'sorry': True, 'unfortunately': True}, 'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'u': True}, 'Positive'),
#  ({':)': True, 'believe': True, 'enough': True, 'salute': True, 'trust': True},
#   'Positive'),
#  ({':(': True, 'amin': True}, 'Negative'),
#  ({':(': True, 'sad': True}, 'Negative'),
#  ({':)': True,
#    'act': True,
#    'always': True,
#    'forward': True,
#    'giggle': True,
#    'great': True,
#    'looking': True,
#    'loop': True,
#    'love': True,
#    'two': True},
#   'Positive'),
#  ({':(': True,
#    'game': True,
#    'stay': True,
#    'trying': True,
#    'watch': True,
#    'work': True},
#   'Negative'),
#  ({':(': True, 'rain': True}, 'Negative'),
#  ({':(': True, 'get': True, 'hard': True, 'notice': True, 'youu': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'honesty': True,
#    'lonely': True,
#    'true': True,
#    'word': True},
#   'Negative'),
#  ({'#bajrangibhaijaanhighestweek1': True,
#    ':d': True,
#    'must': True,
#    'watch': True},
#   'Positive'),
#  ({'3rd': True,
#    ':(': True,
#    'barkada': True,
#    'hyperbullies': True,
#    'like': True,
#    'mag': True,
#    'mi': True,
#    'miss': True,
#    'nawwwee': True,
#    'nga': True,
#    'rajud': True,
#    'seatmates': True,
#    'tong': True,
#    'yr': True},
#   'Negative'),
#  ({'get': True, 'goat': True, 'scar': True}, 'Negative'),
#  ({':d': True,
#    'background': True,
#    'love': True,
#    'remove': True,
#    'till': True,
#    'ty': True,
#    'used': True},
#   'Positive'),
#  ({'::': True, 'learn': True, 'spell': True}, 'Positive'),
#  ({':(': True,
#    'girl': True,
#    'next': True,
#    'poor': True,
#    'prey': True,
#    'yeah': True},
#   'Negative'),
#  ({'#teamfollowback': True,
#    ':-)': True,
#    'back': True,
#    'everyone': True,
#    'follow': True},
#   'Positive'),
#  ({':)': True, 'back': True, 'done': True, 'like': True, '—': True, '😊': True},
#   'Positive'),
#  ({'#braindots': True, 'brain': True, 'dots': True, "i'm": True, 'play': True},
#   'Positive'),
#  ({':)': True, 'fback': True}, 'Positive'),
#  ({':)': True, 'welcome': True}, 'Positive'),
#  ({'#justiceforsandrabland': True,
#    '#sandrabland': True,
#    ':(': True,
#    'already': True,
#    'dead': True,
#    'disturb': True,
#    'mug': True,
#    'poor': True,
#    'shot': True,
#    'show': True,
#    'woman': True},
#   'Negative'),
#  ({'#ff': True,
#    '-->': True,
#    '10': True,
#    ':)': True,
#    'follow': True,
#    'loner': True,
#    'please': True,
#    'side': True},
#   'Positive'),
#  ({'#عن': True, '#غردلي': True, ':)': True, 'smile': True, 'sunnah': True},
#   'Positive'),
#  ({':(': True, "what's": True, 'wrong': True}, 'Negative'),
#  ({':(': True, 'get': True, 'right': True, 'sick': True, 'time': True},
#   'Negative'),
#  ({'emon': True}, 'Positive'),
#  ({':-)': True, 'pinter': True}, 'Positive'),
#  ({'#zayniscomingbackonjuly26': True,
#    ':(': True,
#    'guy': True,
#    'please': True,
#    'stop': True},
#   'Negative'),
#  ({'#amateur': True,
#    '#hottie': True,
#    '#kik': True,
#    '#kikmenow': True,
#    '#sfs': True,
#    '#snapme': True,
#    '#summer': True,
#    '837': True,
#    ':(': True,
#    'kik': True,
#    'plawnew': True},
#   'Negative'),
#  ({'..': True,
#    ':(': True,
#    'anyone': True,
#    'enough': True,
#    'fair': True,
#    'fuck': True,
#    'seem': True,
#    'tad': True,
#    'wiper': True,
#    'would': True,
#    '😔': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    ';(': True,
#    'enough': True,
#    'stop': True,
#    'whit': True},
#   'Negative'),
#  ({':)': True,
#    '<3': True,
#    'bam': True,
#    'bestfriend': True,
#    'follow': True,
#    'hi': True,
#    'lot': True,
#    'love': True,
#    'see': True,
#    'warsaw': True,
#    'x6': True},
#   'Positive'),
#  ({':(': True, 'avi': True, 'change': True, 'usanele': True, 'wanna': True},
#   'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'mind': True}, 'Positive'),
#  ({':)': True, 'make': True}, 'Positive'),
#  ({':d': True, 'okay': True, 'start': True}, 'Positive'),
#  ({':(': True, 'afterbirth': True, 'want': True}, 'Negative'),
#  ({'4-5': True,
#    ':-(': True,
#    'days': True,
#    'finals': True,
#    'kaslkdja': True,
#    'lol': True,
#    'week': True,
#    'yes': True},
#   'Negative'),
#  ({':(': True,
#    'go': True,
#    'last': True,
#    'lovely': True,
#    'night': True,
#    'party': True,
#    'see': True,
#    'shame': True,
#    'would': True,
#    'x': True},
#   'Negative'),
#  ({':)': True,
#    'getting': True,
#    'mom': True,
#    'much': True,
#    'thank': True,
#    'tickets': True},
#   'Positive'),
#  ({':(': True,
#    'awww': True,
#    'baby': True,
#    'dream': True,
#    'team': True,
#    'ylona': True},
#   'Negative'),
#  ({':(': True, 'follow': True, 'please': True}, 'Negative'),
#  ({'#hugs': True,
#    '...': True,
#    ':)': True,
#    'hope': True,
#    'ohh': True,
#    'till': True},
#   'Positive'),
#  ({':-)': True,
#    'back': True,
#    'dont': True,
#    'get': True,
#    'havent': True,
#    'know': True,
#    'much': True,
#    'tbh': True,
#    'tell': True,
#    'u': True,
#    'us': True,
#    'yet': True},
#   'Positive'),
#  ({':d': True,
#    'couple': True,
#    'dark': True,
#    'fuckin': True,
#    'gonna': True,
#    'good': True,
#    'hard': True,
#    'lol': True,
#    'minute': True,
#    'morning': True,
#    'rain': True,
#    'really': True},
#   'Positive'),
#  ({':d': True,
#    ';)': True,
#    'egypt': True,
#    'good': True,
#    'luck': True,
#    'wait': True},
#   'Positive'),
#  ({':(': True, 'allow': True, 'blood': True, 'give': True, "i'm": True},
#   'Negative'),
#  ({':(': True,
#    'close': True,
#    'could': True,
#    'find': True,
#    'header': True,
#    'help': True,
#    'layout': True,
#    'match': True,
#    'someone': True},
#   'Negative'),
#  ({':)': True,
#    'august': True,
#    'diary': True,
#    'firm': True,
#    'know': True,
#    'let': True,
#    'need': True,
#    'potentially': True,
#    'stuff': True,
#    'sure': True},
#   'Positive'),
#  ({':-(': True, 'cream': True, 'free': True, 'ice': True, 'want': True},
#   'Negative'),
#  ({':(': True, 'awake': True, 'even': True}, 'Negative'),
#  ({':)': True,
#    'agnes': True,
#    'email': True,
#    'hi': True,
#    'please': True,
#    'sam': True,
#    'socialmedia.co.uk': True},
#   'Positive'),
#  ({':)': True, 'lorna': True, 'problem': True}, 'Positive'),
#  ({':)': True, 'prob': True}, 'Positive'),
#  ({':(': True, 'hi': True, 'love': True, 'u': True}, 'Negative'),
#  ({':(': True,
#    'abt': True,
#    'afraid': True,
#    'girlll': True,
#    'hear': True,
#    'im': True,
#    'indies': True,
#    'island': True,
#    'lol': True,
#    'possibly': True,
#    'tsunami': True,
#    'u': True,
#    'us': True,
#    'west': True},
#   'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'u': True}, 'Positive'),
#  ({':(': True,
#    'app': True,
#    'confuse': True,
#    'countdown': True,
#    'desktop': True,
#    'function': True,
#    "i'm": True,
#    'live': True,
#    'still': True,
#    'v': True,
#    'watch': True},
#   'Negative'),
#  ({'1': True,
#    ':)': True,
#    'arrive': True,
#    'day': True,
#    'follower': True,
#    'new': True,
#    'stats': True,
#    'unfollowers': True,
#    'via': True},
#   'Positive'),
#  ({':)': True, 'aww': True, 'kind': True, 'love': True, 'men': True},
#   'Positive'),
#  ({':(': True, 'feel': True, 'yah': True}, 'Negative'),
#  ({':(': True,
#    'didnt': True,
#    'everyone': True,
#    'go': True,
#    'please': True,
#    'tell': True,
#    'vidcon': True},
#   'Negative'),
#  ({':)': True,
#    'fabulous': True,
#    'fantastic': True,
#    'friday': True,
#    'keep': True,
#    'work': True},
#   'Positive'),
#  ({':)': True,
#    'acorn': True,
#    'advanced': True,
#    'apart': True,
#    'c64': True,
#    'considerably': True,
#    'cpu': True,
#    'originally': True,
#    'program': True,
#    'since': True,
#    'way': True,
#    "why'd": True},
#   'Positive'),
#  ({'#needicecreamnow': True,
#    '#ubericecream': True,
#    ':(': True,
#    'cancel': True,
#    'cream': True,
#    'get': True,
#    'ice': True,
#    'keep': True,
#    'leeds': True,
#    'trying': True},
#   'Negative'),
#  ({'#مطعم_هاشم': True,
#    ':-)': True,
#    'a7la': True,
#    'bdayt': True,
#    'mnwreeen': True,
#    'season': True,
#    'yummy': True},
#   'Positive'),
#  ({':)': True, '<3': True, 'glad': True}, 'Positive'),
#  ({':(': True, 'feel': True, 'late': True, 'place': True}, 'Negative'),
#  ({':(': True,
#    'aw': True,
#    'miss': True,
#    'shame': True,
#    "that's": True,
#    'think': True,
#    "we'll": True},
#   'Negative'),
#  ({':)': True,
#    '<3': True,
#    'bam': True,
#    'bestfriend': True,
#    'follow': True,
#    'hi': True,
#    'lot': True,
#    'love': True,
#    'see': True,
#    'warsaw': True,
#    'x14': True},
#   'Positive'),
#  ({':(': True, 'mate': True, 'yet': True}, 'Negative'),
#  ({':d': True, 'lol': True, 'makes': True, 'much': True, 'sense': True},
#   'Positive'),
#  ({':d': True, 'honour': True, "i'm": True}, 'Positive'),
#  ({':(': True,
#    'bath': True,
#    'love': True,
#    'recuerda': True,
#    'tanto': True,
#    'waiting': True},
#   'Negative'),
#  ({':(': True,
#    'bc': True,
#    'bracelet': True,
#    'feel': True,
#    'forget': True,
#    'naked': True,
#    'watch': True,
#    'wrist': True},
#   'Negative'),
#  ({':d': True, 'blue': True, 'eye': True, 'guys': True}, 'Positive'),
#  ({':(': True,
#    'best': True,
#    'canadian': True,
#    'dinner': True,
#    'enjoyed': True,
#    'family': True,
#    'holiday': True,
#    'last': True,
#    'night': True,
#    "we're": True,
#    'well': True},
#   'Negative'),
#  ({':-(': True,
#    'ask': True,
#    'bathroom': True,
#    'enjoy': True,
#    'go': True,
#    "i'm": True,
#    'really': True,
#    'show': True,
#    'though': True},
#   'Negative'),
#  ({':(': True,
#    'aww': True,
#    'chicken': True,
#    'cow': True,
#    'farm': True,
#    'fruit': True,
#    'go': True,
#    'grandma': True,
#    "grandpa's": True,
#    'help': True,
#    'horse': True,
#    'lot': True,
#    'sheeps': True,
#    "there's": True,
#    'vegetable': True,
#    'want': True},
#   'Negative'),
#  ({'326': True,
#    ':(': True,
#    'beli̇eve': True,
#    'follow': True,
#    'justi̇n': True,
#    'love': True,
#    'much': True,
#    'please': True,
#    'wi̇ll': True,
#    'x15': True,
#    '♛': True,
#    '》': True,
#    'ｍｅ': True,
#    'ｓｅｅ': True},
#   'Negative'),
#  ({':-)': True, 'thanks': True}, 'Positive'),
#  ({':d': True, 'haha': True, 'x': True}, 'Positive'),
#  ({':(': True, 'cake': True, 'plsssssss': True, 'red': True, 'velvet': True},
#   'Negative'),
#  ({':(': True, 'nightmare': True}, 'Negative'),
#  ({':(': True, 'hate': True, 'time': True, 'zone': True}, 'Negative'),
#  ({':(': True, 'day': True, 'fuck': True, '\U000fe196': True}, 'Negative'),
#  ({':(': True,
#    'bad': True,
#    'feel': True,
#    'felt': True,
#    'first': True,
#    'h': True,
#    'know': True,
#    'lmao': True,
#    'louis': True,
#    'meet': True,
#    'ohhh': True,
#    'time': True,
#    'wanna': True},
#   'Negative'),
#  ({':(': True, 'im': True, 'sure': True, 'tho': True}, 'Negative'),
#  ({'..': True,
#    ':)': True,
#    'could': True,
#    'every': True,
#    'late': True,
#    'night': True,
#    'put': True,
#    'sleep': True,
#    'storm': True,
#    'thunderstorm': True},
#   'Positive'),
#  ({'#foreveralone': True,
#    '..': True,
#    ':d': True,
#    'always': True,
#    'bill': True,
#    'matter': True,
#    'pay': True},
#   'Positive'),
#  ({':(': True,
#    'ago': True,
#    'along': True,
#    'asleep': True,
#    "can't": True,
#    'fall': True,
#    'gn': True,
#    'say': True,
#    'time': True},
#   'Negative'),
#  ({':)': True,
#    'copy': True,
#    'file': True,
#    'movie': True,
#    'neobytes': True,
#    'notice': True,
#    'pictures': True,
#    'pirate': True,
#    'seed': True,
#    'takedown': True,
#    'universal': True},
#   'Positive'),
#  ({':(': True, 'mean': True, 'offer': True}, 'Negative'),
#  ({':)': True, 'familiar': True, 'ha': True, 'sound': True}, 'Positive'),
#  ({':(': True, 'meet': True, 'wanna': True}, 'Negative'),
#  ({':-)': True, 'alex': True, 'thanks': True}, 'Positive'),
#  ({':-)': True, 'brilliant': True}, 'Positive'),
#  ({'...': True, ':-(': True, 'like': True, 'moment': True}, 'Negative'),
#  ({':(': True,
#    'grabe': True,
#    'guy': True,
#    'ka': True,
#    'power': True,
#    'smell': True,
#    'uuughhhh': True},
#   'Negative'),
#  ({'>:(': True,
#    'appointment': True,
#    'awful': True,
#    'feel': True,
#    'go': True,
#    "i'd": True,
#    'like': True,
#    'ok': True,
#    'since': True,
#    'tomorrow': True},
#   'Negative'),
#  ({':)': True, 'kind': True}, 'Positive'),
#  ({':(': True,
#    'hear': True,
#    'hug': True,
#    "i'm": True,
#    'join': True,
#    'sodders': True,
#    'sorry': True},
#   'Negative'),
#  ({':(': True,
#    'annoying': True,
#    'evan': True,
#    'give': True,
#    'must': True,
#    'oh': True,
#    'opt': True,
#    'option': True,
#    'text': True},
#   'Negative'),
#  ({':)': True, 'problem': True, 'yeah': True}, 'Positive'),
#  ({':(': True, 'lucky': True}, 'Negative'),
#  ({':(': True,
#    'able': True,
#    'even': True,
#    'fun': True,
#    'see': True,
#    'though': True},
#   'Negative'),
#  ({':(': True, 'always': True, 'miss': True, 'something': True, 'wifi': True},
#   'Negative'),
#  ({':(': True,
#    'bet': True,
#    'calm': True,
#    'happen': True,
#    'start': True,
#    'try': True,
#    'wonder': True,
#    '“': True,
#    '”': True,
#    '🎂': True,
#    '🏻': True,
#    '🙏': True},
#   'Negative'),
#  ({':(': True, 'already': True, 'miss': True}, 'Negative'),
#  ({':)': True,
#    'analyze': True,
#    'read': True,
#    'team': True,
#    'thank': True,
#    "we're": True,
#    'within': True},
#   'Positive'),
#  ({':(': True, 'hey': True, 'someone': True, 'text': True}, 'Negative'),
#  ({'#akshaymostlovedsuperstarever': True,
#    ':)': True,
#    'awww': True,
#    'doubt': True,
#    'lovely': True,
#    'trend': True},
#   'Positive'),
#  ({'#notanapology': True, ':-)': True, 'pick': True, 'please': True},
#   'Positive'),
#  ({':(': True, 'head': True, 'kill': True, 'today': True}, 'Negative'),
#  ({':(': True,
#    'funny': True,
#    'life': True,
#    'say': True,
#    'someone': True,
#    'story': True,
#    'tell': True,
#    'thing': True},
#   'Negative'),
#  ({':)': True, 'enjoy': True, 'jessica': True, 'welcome': True}, 'Positive'),
#  ({'#psygustokita': True,
#    ':(': True,
#    "angelo's": True,
#    'face': True,
#    'listen': True,
#    'yna': True},
#   'Negative'),
#  ({'#frequentflyer': True, ':)': True, 'join': True, 'program': True},
#   'Positive'),
#  ({':)': True,
#    'admin': True,
#    'bye': True,
#    'enjoy': True,
#    'go': True,
#    'guys': True,
#    'hope': True,
#    'lukris': True,
#    'update': True},
#   'Positive'),
#  ({':d': True,
#    'high': True,
#    'kid': True,
#    'stool': True,
#    'three': True,
#    'topple': True,
#    'usually': True,
#    'wait': True},
#   'Positive'),
#  ({'4-5': True,
#    ':(': True,
#    'arrive': True,
#    'day': True,
#    'even': True,
#    'holiday': True,
#    'shipping': True,
#    'shoe': True,
#    'take': True,
#    'today': True,
#    'want': True,
#    'way': True},
#   'Negative'),
#  ({':(': True, 'stalker': True}, 'Negative'),
#  ({'26': True,
#    ':-(': True,
#    'back': True,
#    'come': True,
#    'guy': True,
#    'july': True,
#    'many': True,
#    'say': True,
#    'srsly': True,
#    'time': True,
#    'zayn': True},
#   'Negative'),
#  ({':)': True, 'fun': True, 'great': True, 'like': True, 'look': True},
#   'Positive'),
#  ({'#morefuninthephilippines': True,
#    '#summer': True,
#    ':)': True,
#    'caramoan': True,
#    'celebrating': True,
#    'island': True,
#    'islands': True,
#    'lahos': True,
#    'life': True},
#   'Positive'),
#  ({'(:': True, 'anytime': True, 'lil': True, 'nigga': True}, 'Negative'),
#  ({':)': True,
#    'daughter': True,
#    'day': True,
#    'even': True,
#    'folk': True,
#    'go': True,
#    'great': True,
#    'morning': True,
#    'mother': True,
#    'nice': True,
#    'rain': True,
#    'though': True,
#    'today': True,
#    'xx': True},
#   'Positive'),
#  ({':(': True, 'happen': True, 'let': True, 'life': True, 'real': True},
#   'Negative'),
#  ({':(': True, 'case': True, 'frighten': True, 'get': True, 'really': True},
#   'Negative'),
#  ({':(': True, 'sorry': True}, 'Negative'),
#  ({':)': True,
#    'answer': True,
#    'completely': True,
#    'course': True,
#    'like': True,
#    'understand': True,
#    'would': True},
#   'Positive'),
#  ({':)': True,
#    'alternative': True,
#    'great': True,
#    'nowadays': True,
#    'viable': True},
#   'Positive'),
#  ({':d': True,
#    'always': True,
#    'ever': True,
#    'expand': True,
#    "i'm": True,
#    'inaccessible': True,
#    'know': True,
#    'lemme': True,
#    'library': True,
#    'likewise': True,
#    'music': True,
#    'open': True,
#    'recs': True,
#    'want': True},
#   'Positive'),
#  ({':(': True, 'give': True, 'layout': True, 'niall': True, 'someone': True},
#   'Negative'),
#  ({':(': True,
#    'harriet': True,
#    'leave': True,
#    'still': True,
#    'though': True,
#    'want': True},
#   'Negative'),
#  ({':-)': True, 'say': True, 'would': True}, 'Positive'),
#  ({':(': True,
#    'already': True,
#    'aww': True,
#    'come': True,
#    'good': True,
#    'hey': True,
#    "i've": True,
#    'leave': True,
#    'night': True,
#    'say': True,
#    'see': True,
#    'sooner': True,
#    'would': True,
#    'x': True},
#   'Negative'),
#  ({':)': True,
#    'canopy': True,
#    'fall': True,
#    'farm': True,
#    'friday': True,
#    'happy': True,
#    'leaf': True,
#    'love': True,
#    'maple': True,
#    'secrets': True,
#    'syrup': True,
#    'xx': True},
#   'Positive'),
#  ({':)': True,
#    'cute': True,
#    'fun': True,
#    'good': True,
#    'guy': True,
#    'hey': True,
#    'make': True,
#    'minion': True,
#    'slot': True,
#    'suggestion': True,
#    'would': True},
#   'Positive'),
#  ({':(': True,
#    '<3': True,
#    'game': True,
#    'nobody': True,
#    'please': True,
#    'stream': True},
#   'Negative'),
#  ({'..': True,
#    ':d': True,
#    'late': True,
#    'match': True,
#    'night': True,
#    'till': True,
#    'watch': True,
#    "y'day": True},
#   'Positive'),
#  ({'#sfvbeta': True,
#    ':)': True,
#    'cool': True,
#    'guys': True,
#    'release': True,
#    'work': True},
#   'Positive'),
#  ({':)': True,
#    'follow': True,
#    'get': True,
#    'hello': True,
#    'job': True,
#    'opportunities': True,
#    'youth': True},
#   'Positive'),
#  ({'..': True,
#    '...': True,
#    ':)': True,
#    'fine': True,
#    'friday': True,
#    'friend': True,
#    'gorgeous': True,
#    'xo': True},
#   'Positive'),
#  ({':(': True,
#    'doctor': True,
#    'hurt': True,
#    'oh': True,
#    'visit': True,
#    'well': True},
#   'Negative'),
#  ({':(': True, 'reaction': True}, 'Negative'),
#  ({'600': True,
#    '8': True,
#    ':-(': True,
#    'alert': True,
#    'community': True,
#    'cost': True,
#    'far': True,
#    'get': True,
#    'k': True,
#    'odoo': True,
#    'partner': True,
#    'security': True,
#    'spirit': True,
#    '£': True},
#   'Negative'),
#  ({':)': True,
#    'another': True,
#    'avoid': True,
#    'body': True,
#    'good': True,
#    'introduce': True,
#    'laboratory': True,
#    'say': True,
#    'speaker': True,
#    'stress': True,
#    'ted': True,
#    'thought': True,
#    'way': True},
#   'Positive'),
#  ({':(': True, 'friend': True}, 'Negative'),
#  ({':-)': True,
#    'cause': True,
#    'cheer': True,
#    'day': True,
#    'haha': True,
#    'kindly': True,
#    'let': True,
#    'maybe': True,
#    'might': True,
#    'one': True,
#    'thanks': True},
#   'Positive'),
#  ({':)': True,
#    'afterwards': True,
#    'back': True,
#    'figure': True,
#    'get': True,
#    'gotta': True,
#    'hi': True,
#    'likely': True,
#    'surrey': True,
#    'thanks': True,
#    'thing': True,
#    'time': True,
#    'tonight': True,
#    'wrap': True},
#   'Positive'),
#  ({':)': True, 'ah': True, 'ok': True, 'wonder': True}, 'Positive'),
#  ({'#nailedit': True,
#    '#ourdisneyinfinity': True,
#    ':d': True,
#    "i'm": True,
#    'pretty': True,
#    'proud': True,
#    'yeah': True},
#   'Positive'),
#  ({':-)': True, 'corridor': True, 'dare': True, 'run': True}, 'Positive'),
#  ({':(': True, 'raining': True}, 'Negative'),
#  ({':)': True,
#    'good': True,
#    'know': True,
#    'miss': True,
#    'monica': True,
#    'sound': True,
#    'yeah': True,
#    '💪': True},
#   'Positive'),
#  ({'#amazon': True,
#    '#hot': True,
#    '#kikmeguys': True,
#    '#kikmenow': True,
#    '#snapchat': True,
#    '#snapme': True,
#    ':)': True,
#    'lynettelowe': True,
#    'snapchat': True},
#   'Positive'),
#  ({':(': True, 'darlin': True, "i'm": True, 'sorry': True}, 'Negative'),
#  ({':)': True,
#    'appreciate': True,
#    'botanical': True,
#    'follow': True,
#    'hear': True,
#    'soap': True},
#   'Positive'),
#  ({':(': True,
#    'go': True,
#    "i'm": True,
#    'op': True,
#    'sad': True,
#    'see': True,
#    'sure': True,
#    'thapelo': True,
#    'would': True},
#   'Negative'),
#  ({':)': True, 'fback': True}, 'Positive'),
#  ({'#cute': True,
#    '#hotairballoon': True,
#    '#retweet': True,
#    ':)': True,
#    'air': True,
#    'airforce': True,
#    'balloon': True,
#    'city': True,
#    'clark': True,
#    'festival': True,
#    'field': True,
#    'flying': True,
#    'hot': True,
#    'pampanga': True,
#    'panda': True},
#   'Positive'),
#  ({'..': True,
#    ':)': True,
#    'book': True,
#    'btw': True,
#    'explorers': True,
#    'finish': True,
#    'kind': True,
#    'little': True,
#    'next': True,
#    'thank': True,
#    "that's": True,
#    'work': True,
#    'year': True},
#   'Positive'),
#  ({':)': True, 'ahahah': True, "i'll": True}, 'Positive'),
#  ({':(': True, 'sore': True, 'throat': True}, 'Negative'),
#  ({':(': True,
#    'early': True,
#    'go': True,
#    'lol': True,
#    'never': True,
#    'sleep': True},
#   'Negative'),
#  ({':(': True, 'single': True, 'untruth': True}, 'Negative'),
#  ({':(': True,
#    'back': True,
#    'complaint': True,
#    'detail': True,
#    'dm': True,
#    'get': True,
#    'hi': True,
#    'locate': True,
#    'original': True,
#    'pls': True,
#    'product': True,
#    'unable': True,
#    'unfortunately': True,
#    'us': True,
#    "we'll": True,
#    "we're": True},
#   'Negative'),
#  ({':(': True, 'brown': True, 'hair': True, 'miss': True}, 'Negative'),
#  ({'3': True,
#    ':-)': True,
#    'bit': True,
#    'dance': True,
#    'definitely': True,
#    'everyone': True,
#    'friday': True,
#    'happy': True,
#    'hour': True,
#    'last': True,
#    'night': True,
#    'salsa': True,
#    'tire': True,
#    'worth': True},
#   'Positive'),
#  ({':(': True, 'back': True, 'follow': True}, 'Negative'),
#  ({':(': True,
#    'around': True,
#    'hawako': True,
#    'kimaaaaaani': True,
#    'need': True,
#    'people': True,
#    'prisssss': True,
#    'talk-kama': True,
#    'waa': True},
#   'Negative'),
#  ({'#masaantoday': True, ':-)': True, 'team': True, 'wahoo': True},
#   'Positive'),
#  ({':)': True, 'work': True, 'yes': True}, 'Positive'),
#  ({'...': True,
#    ':(': True,
#    'back': True,
#    'get': True,
#    'lmao': True,
#    'really': True,
#    'serious': True},
#   'Negative'),
#  ({'...': True, ':(': True, 'bullshit': True}, 'Negative'),
#  ({':(': True,
#    '___': True,
#    'chance': True,
#    'enough': True,
#    'fault': True,
#    'good': True,
#    "he's": True,
#    'let': True,
#    'miss': True,
#    'pls': True,
#    'think': True},
#   'Negative'),
#  ({':(': True,
#    'bae': True,
#    'fabina': True,
#    'ik': True,
#    'mean': True,
#    'omg': True,
#    'otp': True,
#    '😂': True},
#   'Negative'),
#  ({':)': True,
#    'awww': True,
#    'guy': True,
#    'safe': True,
#    'thanks': True,
#    'travel': True,
#    'weekend': True,
#    'wicked': True,
#    'wishing': True,
#    'x': True},
#   'Positive'),
#  ({'#bbloggers': True,
#    '#beauty': True,
#    '#makeup': True,
#    ':(': True,
#    'another': True,
#    'dissapointed': True,
#    'review': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'age': True,
#    'ago': True,
#    'cake': True,
#    "he's": True,
#    'like': True,
#    'meet': True,
#    'premiere': True,
#    'skyfall': True,
#    'though': True,
#    'yummy': True},
#   'Negative'),
#  ({':d': True, 'super': True}, 'Positive'),
#  ({':(': True,
#    'duck': True,
#    'fucking': True,
#    'nice': True,
#    'ur': True,
#    'weather': True},
#   'Negative'),
#  ({':-)': True,
#    'appreciate': True,
#    'mate': True,
#    'much': True,
#    'thanks': True},
#   'Positive'),
#  ({':)': True,
#    'back': True,
#    'desk': True,
#    'get': True,
#    'huhu': True,
#    'leave': True,
#    'o_o': True,
#    'orz': True,
#    'saw': True,
#    'shet': True,
#    'tweet': True},
#   'Positive'),
#  ({':d': True, 'bro': True, 'thanks': True, 'x': True}, 'Positive'),
#  ({'#goldcoast': True, ':)': True, 'tomorrow': True}, 'Positive'),
#  ({':(': True, 'one': True}, 'Negative'),
#  ({':(': True,
#    'find': True,
#    'fun': True,
#    'hour': True,
#    'lunch': True,
#    'nap': True,
#    'somewhere': True,
#    'try': True},
#   'Negative'),
#  ({':)': True, 'thanks': True}, 'Positive'),
#  ({':p': True,
#    'act': True,
#    'app': True,
#    'call': True,
#    'etl': True,
#    'imply': True,
#    'in-house': True,
#    'katamari': True,
#    'layer': True,
#    'mischievousness': True,
#    'name': True,
#    'warehouse': True,
#    'well': True,
#    '…': True},
#   'Positive'),
#  ({':)': True, 'like': True, '—': True, '🐢': True}, 'Positive'),
#  ({':)': True, 'glad': True, 'like': True}, 'Positive'),
#  ({':)': True, 'give': True, 'please': True, 'thanks': True}, 'Positive'),
#  ({':(': True,
#    'asleep': True,
#    'back': True,
#    "can't": True,
#    'fall': True,
#    'really': True},
#   'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'u': True}, 'Positive'),
#  ({':)': True, 'gd': True, 'marty': True, 'thanks': True, 'weekend': True},
#   'Positive'),
#  ({':)': True, 'bond': True, 'jgh': True, 'niggs': True}, 'Positive'),
#  ({'...': True, ':-(': True, 'beach': True, 'day': True, 'last': True},
#   'Negative'),
#  ({':d': True, 'go': True, 'great': True, 'hope': True, 'vacation': True},
#   'Positive'),
#  ({':(': True,
#    'ape': True,
#    'come': True,
#    'empty': True,
#    'home': True,
#    'house': True},
#   'Negative'),
#  ({':)': True, 'back': True, 'follow': True, 'u': True}, 'Positive'),
#  ({':)': True,
#    'along': True,
#    'dream': True,
#    'get': True,
#    'go': True,
#    'good': True,
#    'im': True,
#    'roomie': True,
#    'sign': True,
#    'unknown': True},
#   'Positive'),
#  ({'1:30': True,
#    ':)': True,
#    'arond': True,
#    'asleep': True,
#    'consider': True,
#    'exhaust': True,
#    'fell': True,
#    'late': True,
#    'really': True,
#    'work': True},
#   'Positive'),
#  ({':)': True, 'kalle': True, 'welcome': True}, 'Positive'),
#  ({':(': True,
#    'absolute': True,
#    'close': True,
#    'cry': True,
#    'fucking': True,
#    'hard': True,
#    'manila': True,
#    'see': True,
#    'show': True,
#    'time': True,
#    'world': True},
#   'Negative'),
#  ({':(': True, 'freezing': True, 'work': True}, 'Negative'),
#  ({':(': True,
#    'baby': True,
#    'children': True,
#    'day': True,
#    'dozen': True,
#    'killed': True,
#    'parents': True,
#    'selfie': True,
#    'shark': True},
#   'Negative'),
#  ({':(': True, 'head': True, 'hurt': True, 'ugh': True}, 'Negative'),
#  ({':)': True,
#    'enjoy': True,
#    'guy': True,
#    'hey': True,
#    'new': True,
#    'page': True,
#    "that's": True},
#   'Positive'),
#  ({'...': True,
#    ':)': True,
#    'beautiful': True,
#    'like': True,
#    'russia': True,
#    'summer': True,
#    'winter': True},
#   'Positive'),
#  ({'#amateur': True,
#    '#hannibal': True,
#    '#kikmeboys': True,
#    '#kikmenow': True,
#    '#kiksexting': True,
#    '#seduce': True,
#    '#snapchat': True,
#    '18': True,
#    ':(': True,
#    'fun': True,
#    'lilybutle': True,
#    'looking': True,
#    'snapchat': True},
#   'Negative'),
#  ({':)': True,
#    'could': True,
#    'dm': True,
#    'get': True,
#    'louis': True,
#    'maybe': True,
#    'oh': True,
#    'please': True,
#    'quote': True,
#    'second': True,
#    'tweet': True},
#   'Positive'),
#  ({':)': True,
#    'construction': True,
#    'design': True,
#    'garden': True,
#    'park': True,
#    'plant': True,
#    'rhs': True,
#    'show': True,
#    'stunning': True,
#    'tatton': True,
#    "there's": True,
#    'wonderful': True},
#   'Positive'),
#  ({':(': True, 'acc': True, "can't": True, 'look': True}, 'Negative'),
#  ({':(': True,
#    'french': True,
#    'miss': True,
#    'mixer': True,
#    'much': True,
#    '💜': True},
#   'Negative'),
#  ({':(': True,
#    'ba': True,
#    'go': True,
#    "i'm": True,
#    'ka': True,
#    'kailan': True,
#    'may': True,
#    'tix': True},
#   'Negative'),
#  ({'#parijat': True,
#    '#sad': True,
#    '#willmissyouparijat': True,
#    ':-(': True,
#    'know': True,
#    'life': True,
#    'picture': True,
#    'see': True,
#    'want': True},
#   'Negative'),
#  ({':d': True, 'ever': True, 'heart': True, 'kind': True, 'know': True},
#   'Positive'),
#  ({':-(': True,
#    'bv': True,
#    'fail': True,
#    'huhu': True,
#    'one': True,
#    'pls': True,
#    'pray': True,
#    'sobrang': True,
#    'subj': True,
#    'think': True,
#    '😭': True},
#   'Negative'),
#  ({':(': True, 'handover': True, 'smooth': True}, 'Negative'),
#  ({':(': True, 'bring': True, 'key': True}, 'Negative'),
#  ({':-(': True,
#    'damn': True,
#    'good': True,
#    'hella': True,
#    'least': True,
#    'matter': True,
#    'oh': True,
#    'really': True,
#    'suck': True,
#    'thank': True,
#    "that's": True,
#    'time': True,
#    'u': True,
#    'yes': True},
#   'Negative'),
#  ({':(': True, 'cute': True}, 'Negative'),
#  ({'...': True,
#    ':(': True,
#    'chesties': True,
#    'every': True,
#    'get': True,
#    'sad': True,
#    'think': True,
#    'time': True},
#   'Negative'),
#  ({'#louisianashooting': True,
#    ':(': True,
#    'cinema': True,
#    'get': True,
#    'go': True,
#    'live': True,
#    'people': True,
#    'shot': True,
#    'wanna': True,
#    'world': True},
#   'Negative'),
#  ({':(': True, 'awwwwww': True, 'hear': True, "i'm": True, 'sorry': True},
#   'Negative'),
#  ({':)': True,
#    'charging': True,
#    'early': True,
#    'finally': True,
#    'get': True,
#    'speaker': True,
#    'today': True},
#   'Positive'),
#  ({':)': True, 'morning': True}, 'Positive'),
#  ({':(': True, 'icecream': True, 'leeds': True}, 'Negative'),
#  ({':-(': True,
#    'good': True,
#    'screw': True,
#    'something': True,
#    'think': True,
#    'time': True,
#    'yeah': True},
#   'Negative'),
#  ({'#teampositive': True, ':)': True, 'course': True, 'yes': True},
#   'Positive'),
#  ({'341': True,
#    ':(': True,
#    'beli̇eve': True,
#    'follow': True,
#    'justi̇n': True,
#    'love': True,
#    'much': True,
#    'please': True,
#    'wi̇ll': True,
#    'x15': True,
#    '♛': True,
#    '》': True,
#    'ｍｅ': True,
#    'ｓｅｅ': True},
#   'Negative'),
#  ({':(': True,
#    '<3': True,
#    'episode': True,
#    'forever': True,
#    'intense': True,
#    'kagami': True,
#    'kuroko': True,
#    'last': True,
#    'n': True,
#    'really': True},
#   'Negative'),
#  ({':(': True, 'offend': True}, 'Negative'),
#  ({':(': True,
#    'apple': True,
#    'contact': True,
#    'could': True,
#    'find': True,
#    'hi': True,
#    'one': True,
#    'play': True,
#    'shuffle': True,
#    'song': True,
#    'way': True,
#    'work': True},
#   'Negative'),
#  ({':(': True, 'late': True}, 'Negative'),
#  ({':)': True, 'good': True}, 'Positive'),
#  ({':(': True, 'sorry': True}, 'Negative'),
#  ({'14': True,
#    ':(': True,
#    'back': True,
#    'come': True,
#    'day': True,
#    'get': True,
#    'go': True,
#    "he's": True,
#    'home': True,
# ...
#    '...': True,
#    ':(': True,
#    'abroad': True,
#    'dark': True,
#    'give': True,
#    'leave': True,
#    'light': True,
#    'remain': True,
#    'word': True,
#    'work': True},
#   'Negative'),
#  ({':(': True, 'nighter': True}, 'Negative'),
#  ({':(': True,
#    'citizen': True,
#    'sign': True,
#    'support': True,
#    'try': True,
#    'uk': True},
#   'Negative'),
#  ({':)': True,
#    'bare': True,
#    'delight': True,
#    'earth': True,
#    'feel': True,
#    'foot': True,
#    'forget': True,
#    'gibran': True,
#    'hair': True,
#    'kahlil': True,
#    'long': True,
#    'play': True,
#    'wind': True},
#   'Positive'),
#  ({':-(': True, 'even': True, "i'm": True, 'tire': True}, 'Negative'),
#  ({':(': True, 'eyesight': True, 'happen': True}, 'Negative'),
#  ({'...': True,
#    ':)': True,
#    'friday': True,
#    'hey': True,
#    'lol': True,
#    'morning': True,
#    'wet': True},
#   'Positive'),
#  ({':)': True,
#    'bosch': True,
#    'definitely': True,
#    'last': True,
#    'long': True,
#    'machine': True,
#    'offer': True,
#    'phenomenal': True,
#    'quite': True,
#    'washing': True,
#    "week's": True},
#   'Positive'),
#  ({':)': True,
#    'know': True,
#    'lovely': True,
#    'pic': True,
#    'would': True,
#    'x': True},
#   'Positive'),
#  ({':(': True,
#    'ano': True,
#    'sad': True,
#    'tbh': True,
#    'true': True,
#    'yung': True},
#   'Negative'),
#  ({':(': True, 'date': True, 'yet': True}, 'Negative'),
#  ({'#dota2': True,
#    '#ti5': True,
#    '2015': True,
#    ':)': True,
#    'available': True,
#    'good': True,
#    'pillar': True,
#    'release': True,
#    "sculptor's": True,
#    'store': True,
#    'thing': True},
#   'Positive'),
#  ({':d': True,
#    'crew': True,
#    'garrus': True,
#    'liara': True,
#    'maybe': True,
#    'rest': True},
#   'Positive'),
#  ({':-(': True, 'bully': True, 'cyber': True, 'stop': True}, 'Negative'),
#  ({'2': True,
#    '23': True,
#    '33': True,
#    '90': True,
#    ':)': True,
#    'bible': True,
#    'check': True,
#    'chronicles': True,
#    'complete': True,
#    'day': True,
#    'days': True,
#    'finish': True,
#    'plan': True},
#   'Positive'),
#  ({'#starsquad': True,
#    ':)': True,
#    'awesome': True,
#    'follow': True,
#    'get': True,
#    'please': True,
#    '⭐': True},
#   'Positive'),
#  ({':(': True, 'dad': True, 'say': True, 'sorry': True}, 'Negative'),
#  ({':(': True, 'bby': True, 'imy': True, 'wake': True}, 'Negative'),
#  ({':)': True,
#    'afraid': True,
#    'best': True,
#    'definitely': True,
#    'hi': True,
#    'knowledge': True,
#    'limit': True,
#    'look': True,
#    'maggie': True,
#    'mull': True,
#    'nil': True,
#    'page': True,
#    'place': True,
#    'web': True},
#   'Positive'),
#  ({':-)': True, 'high': True, "i'm": True, 'love': True, 'stash': True},
#   'Positive'),
#  ({':-)': True,
#    "ain't": True,
#    'bc': True,
#    'beautiful': True,
#    'definitely': True,
#    'ever': True,
#    'good': True,
#    'guess': True,
#    'jealous': True,
#    'much': True,
#    'people': True,
#    'somi': True},
#   'Positive'),
#  ({':(': True, 'hate': True, 'messenger': True}, 'Negative'),
#  ({':d': True, 'okay': True, 'thank': True}, 'Positive'),
#  ({':-)': True, 'right': True}, 'Positive'),
#  ({':(': True,
#    'ask': True,
#    'concert': True,
#    'could': True,
#    'cuz': True,
#    'eunhae': True,
#    'last': True,
#    'live': True,
#    'make': True,
#    'since': True,
#    'snapchat': True,
#    'team': True,
#    'think': True},
#   'Negative'),
#  ({':(': True, 'gonna': True, 'longggg': True, 'night': True}, 'Negative'),
#  ({':)': True, 'slr': True, 'som': True, 'sore': True, 'yaa': True},
#   'Positive'),
#  ({':)': True, 'nail': True, 'paint': True, 'pink': True}, 'Positive'),
#  ({':)': True,
#    'amusement': True,
#    'fill': True,
#    'gonna': True,
#    'head': True,
#    "i'm": True,
#    'laugh': True,
#    'life': True,
#    'lol': True,
#    'lot': True,
#    'shake': True},
#   'Positive'),
#  ({':(': True,
#    'complaint': True,
#    'file': True,
#    'last': True,
#    'much': True,
#    'place': True,
#    'plan': True,
#    'police': True,
#    'switch': True,
#    "that's": True,
#    'time': True,
#    'yeah': True,
#    'yelling': True},
#   'Negative'),
#  ({':)': True,
#    'bless': True,
#    'dan': True,
#    'god': True,
#    'greet': True,
#    'meet': True,
#    'soon': True},
#   'Positive'),
#  ({':(': True, 'felt': True, 'good': True, 'life': True, 'never': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'buy': True,
#    'day': True,
#    'far': True,
#    'gift': True,
#    'last': True,
#    'little': True,
#    'munchkin': True,
#    'parting': True,
#    'today': True,
#    'work': True,
#    '…': True},
#   'Negative'),
#  ({':-(': True,
#    'anyway': True,
#    'exception': True,
#    'good': True,
#    'may': True,
#    'mushroom': True,
#    'one': True,
#    'piece': True,
#    'reach': True,
#    'read': True,
#    'rehash': True,
#    'website': True},
#   'Negative'),
#  ({':(': True,
#    'bc': True,
#    'creepy': True,
#    'feel': True,
#    'mianhe': True,
#    'milkeu': True,
#    'pmsl': True,
#    'today': True},
#   'Negative'),
#  ({':(': True,
#    'company': True,
#    'day': True,
#    'jk': True,
#    'mean': True,
#    'pa': True,
#    '💔': True},
#   'Negative'),
#  ({':(': True, 'album': True, 'broadcast': True, 'lose': True}, 'Negative'),
#  ({':(': True, 'feel': True}, 'Negative'),
#  ({':(': True, 'ankle': True}, 'Negative'),
#  ({':)': True,
#    '>:(': True,
#    'crap': True,
#    'esp': True,
#    'fb': True,
#    'go': True,
#    "i'll": True,
#    'millie': True,
#    'page': True,
#    'ppl': True,
#    'straight': True,
#    'sure': True,
#    'talk': True},
#   'Negative'),
#  ({'#flipkartfashionfriday': True,
#    ':)': True,
#    'black': True,
#    'dazzle': True,
#    'double': True,
#    'dress': True,
#    'flared': True,
#    'hey': True,
#    'red': True,
#    'urself': True},
#   'Positive'),
#  ({':(': True, 'know': True}, 'Negative'),
#  ({'327': True,
#    ':(': True,
#    'beli̇eve': True,
#    'follow': True,
#    'justi̇n': True,
#    'love': True,
#    'much': True,
#    'please': True,
#    'wi̇ll': True,
#    'x15': True,
#    '♛': True,
#    '》': True,
#    'ｍｅ': True,
#    'ｓｅｅ': True},
#   'Negative'),
#  ({'...': True,
#    ':(': True,
#    'great': True,
#    'popularity': True,
#    'really': True,
#    'refresh': True,
#    "they're": True,
#    'unique': True},
#   'Negative'),
#  ({':(': True, 'brother': True, 'get': True, 'piss': True}, 'Negative'),
#  ({':)': True, 'couch': True, 'hello': True, 'wave': True}, 'Positive'),
#  ({':(': True, 'tired': True}, 'Negative'),
#  ({':)': True, 'type': True, 'warlock': True}, 'Positive'),
#  ({'#branding': True, '#marketing': True, ':)': True, 'point': True},
#   'Positive'),
#  ({':)': True,
#    'enough': True,
#    'get': True,
#    'number': True,
#    'point': True,
#    'strangely': True,
#    'year': True},
#   'Positive'),
#  ({':(': True, 'dont': True, 'original': True, 'pic': True, 'yes': True},
#   'Negative'),
#  ({'#masaantoday': True, ':)': True}, 'Positive'),
#  ({':d': True, 'live': True, 'summer': True}, 'Positive'),
#  ({'5': True,
#    ':)': True,
#    'fiverr': True,
#    'free': True,
#    'friend': True,
#    'twitter': True,
#    'use': True,
#    'voucher': True},
#   'Positive'),
#  ({'19th': True,
#    ':(': True,
#    'bill': True,
#    'co': True,
#    'full': True,
#    'rent': True,
#    'sept': True,
#    'start': True,
#    "that's": True,
#    'til': True},
#   'Negative'),
#  ({':d': True, 'care': True, 'haha': True}, 'Positive'),
#  ({':)': True,
#    'barcode': True,
#    'charlotte': True,
#    'hiya': True,
#    'look': True,
#    'number': True,
#    'paul': True,
#    'send': True,
#    'take': True,
#    "we'll": True},
#   'Positive'),
#  ({':(': True, 'miss': True}, 'Negative'),
#  ({':(': True, 'share': True}, 'Negative'),
#  ({':-)': True, 'coffee': True, 'mb': True, 'need': True}, 'Positive'),
#  ({':)': True, 'chalut': True}, 'Positive'),
#  ({'#philosophical': True,
#    ':)': True,
#    'actually': True,
#    'beg': True,
#    'differ': True,
#    'less': True,
#    'one': True,
#    'sometimes': True,
#    'would': True},
#   'Positive'),
#  ({':(': True,
#    'benzema': True,
#    'either': True,
#    'get': True,
#    'prefer': True,
#    'though': True,
#    'would': True},
#   'Negative'),
#  ({':-(': True,
#    'baby': True,
#    'chilton': True,
#    'cry': True,
#    'fee': True,
#    'find': True,
#    'goat': True,
#    'help': True,
#    'mother': True,
#    'please': True,
#    'steal': True},
#   'Negative'),
#  ({':(': True,
#    'anymore': True,
#    'base': True,
#    'body': True,
#    "can't": True,
#    'life': True,
#    'stress': True,
#    'upon': True,
#    'yet': True},
#   'Negative'),
#  ({':d': True, 'mate': True, 'sure': True, 'thanks': True, 'worry': True},
#   'Positive'),
#  ({':(': True,
#    'anybody': True,
#    'collection': True,
#    'episode': True,
#    'pa-copy': True,
#    'season': True,
#    'suits': True},
#   'Negative'),
#  ({'...': True,
#    ':)': True,
#    'ahead': True,
#    'bday': True,
#    'great': True,
#    'happy': True,
#    'saar': True,
#    'year': True},
#   'Positive'),
#  ({'6:15': True,
#    '70': True,
#    ':)': True,
#    'currently': True,
#    'degree': True,
#    'fahrenheit': True,
#    'good': True,
#    'pm': True,
#    'really': True,
#    'rn': True,
#    'warm': True},
#   'Positive'),
#  ({':(': True, 'infinite': True, 'win': True}, 'Negative'),
#  ({':(': True,
#    'clever': True,
#    'huh': True,
#    "i'm": True,
#    'like': True,
#    'super': True,
#    'time': True,
#    'two': True,
#    'uh': True},
#   'Negative'),
#  ({'..': True,
#    ':)': True,
#    'act': True,
#    'adult': True,
#    "can't": True,
#    'day': True,
#    'goning': True,
#    'keep': True,
#    'like': True,
#    'make': True,
#    'mom': True,
#    'positive': True,
#    'thos': True},
#   'Positive'),
#  ({':)': True,
#    '<3': True,
#    'bam': True,
#    'bestfriend': True,
#    'follow': True,
#    'hi': True,
#    'lot': True,
#    'love': True,
#    'see': True,
#    'warsaw': True},
#   'Positive'),
#  ({':(': True,
#    'bumi': True,
#    'dari': True,
#    'dihapus': True,
#    'fair': True,
#    'give': True,
#    'hilang': True,
#    'kapan': True,
#    'link': True,
#    'love': True,
#    'muka': True,
#    'oh': True,
#    'read': True,
#    'someone': True,
#    'udah': True,
#    'update': True,
#    'want': True,
#    'war': True,
#    'ya': True,
#    '😢': True},
#   'Negative'),
#  ({'2': True,
#    ':(': True,
#    'ago': True,
#    'caribbean': True,
#    'pack': True,
#    'today': True,
#    'year': True},
#   'Negative'),
#  ({':(': True,
#    'cigar': True,
#    'good': True,
#    'long': True,
#    'man': True,
#    'shame': True,
#    'though': True},
#   'Negative'),
#  ({':(': True,
#    'anything': True,
#    'bae': True,
#    'dont': True,
#    'happen': True,
#    'want': True},
#   'Negative'),
#  ({':(': True,
#    'always': True,
#    'day': True,
#    'finally': True,
#    'follow': True,
#    "i've": True,
#    'ignore': True,
#    'let': True,
#    'please': True,
#    'since': True,
#    'start': True,
#    'support': True,
#    'today': True,
#    '♥': True,
#    '�': True},
#   'Negative'),
#  ({':)': True, 'perfect': True}, 'Positive'),
#  ({':-(': True,
#    'add': True,
#    'cream': True,
#    'gurgaon': True,
#    'ice': True,
#    'location': True,
#    'many': True,
#    'pls': True,
#    'supercars': True},
#   'Negative'),
#  ({':(': True, 'another': True, 'headache': True, 'ridiculous': True},
#   'Negative'),
#  ({':(': True, 'rain': True}, 'Negative'),
#  ({':(': True, 'bore': True, "i'm": True}, 'Negative'),
#  ({':(': True,
#    'alone': True,
#    "can't": True,
#    'day': True,
#    'even': True,
#    'leave': True,
#    'life': True,
#    'live': True,
#    'rest': True,
#    'survive': True,
#    'tell': True},
#   'Negative'),
#  ({':)': True,
#    'ad': True,
#    'course': True,
#    'fast': True,
#    'forward': True,
#    'free': True,
#    'hope': True,
#    "i've": True,
#    'look': True,
#    'rewatches': True,
#    'thank': True,
#    'watch': True,
#    'yeah': True},
#   'Positive'),
#  ({'#mypapamypride': True,
#    '#ourdaughtersourpride': True,
#    ':)': True,
#    'coach': True,
#    'papa': True,
#    'proud': True},
#   'Positive'),
#  ({':(': True,
#    'computer': True,
#    'conversion': True,
#    'crying': True,
#    'data': True,
#    'even': True,
#    'go': True,
#    "i'm": True,
#    'talk': True,
#    'wrong': True},
#   'Negative'),
#  ({':)': True,
#    'go': True,
#    'good': True,
#    'keep': True,
#    'kim': True,
#    'really': True,
#    'stylish': True,
#    'trendy': True},
#   'Positive'),
#  ({':(': True,
#    'ache': True,
#    'give': True,
#    'much': True,
#    'teeth': True,
#    'wisdom': True},
#   'Negative'),
#  ({':(': True,
#    'ate': True,
#    'hard': True,
#    'hi': True,
#    'know': True,
#    'love': True,
#    'maybe': True,
#    'much': True,
#    'right': True,
#    'time': True},
#   'Negative'),
#  ({':(': True, 'answer': True, 'fan': True, 'sleep': True}, 'Negative'),
#  ({':(': True,
#    'bitch': True,
#    'care': True,
#    'day': True,
#    'kill': True,
#    'maggie': True,
#    'psycho': True,
#    'take': True,
#    'twitter': True,
#    'two': True,
#    'vacation': True,
#    'wahhh': True,
#    'want': True},
#   'Negative'),
#  ({'#couple': True,
#    '#hotgirls': True,
#    '#kik': True,
#    '#kiksexting': True,
#    '#omegle': True,
#    '#sex': True,
#    '#travel': True,
#    '76': True,
#    ':(': True,
#    'add': True,
#    'guys': True,
#    'kik': True,
#    'thelock': True},
#   'Negative'),
#  ({':(': True, 'finally': True, 'sending': True}, 'Negative'),
#  ({':d': True,
#    'get': True,
#    'gift': True,
#    'hope': True,
#    'lot': True,
#    'nice': True},
#   'Positive'),
#  ({':d': True, 'congrats': True, 'launch': True}, 'Positive'),
#  ({'11': True,
#    '15': True,
#    ':(': True,
#    'advanced': True,
#    'directx': True,
#    'esnho': True,
#    'node': True,
#    'p2': True,
#    'remove': True,
#    'shading': True,
#    'uploaded': True,
#    'workshop': True},
#   'Negative'),
#  ({'...': True,
#    ':d': True,
#    'ask': True,
#    'hmmm': True,
#    'michael': True,
#    'nikkei': True,
#    'pearson': True,
#    'reputation': True,
#    'woodford': True,
#    'yes': True},
#   'Positive'),
#  ({'#bot': True,
#    ':)': True,
#    'hello': True,
#    'imitatia': True,
#    'leave': True,
#    'mention': True,
#    'michelle': True,
#    'oe': True},
#   'Positive'),
#  ({':(': True, 'awful': True, "that's": True}, 'Negative'),
#  ({':(': True, 'england': True, 'girl': True, "i'm": True, 'lonely': True},
#   'Negative'),
#  ({':(': True, 'getting': True, 'pump': True}, 'Negative'),
#  ({':(': True,
#    'coffee': True,
#    'county': True,
#    'cry': True,
#    'derby': True,
#    'hate': True,
#    'leeds': True,
#    'man': True,
#    'mugs': True,
#    'share': True,
#    'u': True,
#    'unable': True,
#    'united': True},
#   'Negative'),
#  ({':)': True,
#    'blonde': True,
#    'hair': True,
#    'hey': True,
#    'know': True,
#    'swerve': True},
#   'Positive'),
#  ({'2': True,
#    ':(': True,
#    'ahhhhh': True,
#    'go': True,
#    'last': True,
#    'stage': True},
#   'Negative'),
#  ({':)': True,
#    'account': True,
#    'feel': True,
#    'harryxhood': True,
#    'love': True,
#    'nice': True,
#    'pretty': True,
#    'really': True,
#    'talk': True,
#    "that's": True,
#    'upset': True,
#    'yaya': True},
#   'Positive'),
#  ({':(': True, 'care': True, 'muslim': True}, 'Negative'),
#  ({':)': True,
#    'founder': True,
#    'galing': True,
#    'loveyaaaah': True,
#    'ni': True,
#    '⅛': True,
#    '⅞': True,
#    '∞': True,
#    '♥': True},
#   'Positive'),
#  ({':(': True, 'without': True}, 'Negative'),
#  ({':-(': True, 'hurry': True, 'need': True, 'wednesday': True}, 'Negative'),
#  ({':)': True, 'going': True, 'real': True}, 'Positive'),
#  ({':(': True,
#    'day': True,
#    'fight': True,
#    'forgetting': True,
#    'huhu': True,
#    'im': True,
#    'important': True,
#    'sorry': True},
#   'Negative'),
#  ({':)': True,
#    'fact': True,
#    'fun': True,
#    'love': True,
#    'meet': True,
#    'new': True,
#    'people': True},
#   'Positive'),
#  ({':)': True,
#    'city': True,
#    'concert': True,
#    'country': True,
#    'hi': True,
#    "i'll": True,
#    'know': True,
#    'let': True,
#    'like': True,
#    'start': True,
#    'thanks': True,
#    'work': True,
#    'would': True},
#   'Positive'),
#  ({':(': True, "i'm": True, 'jane': True, 'say': True, 'welcome': True},
#   'Negative'),
#  ({':(': True,
#    'allah': True,
#    'juudiciary': True,
#    'may': True,
#    'pakistan': True,
#    'save': True,
#    'us': True},
#   'Negative'),
#  ({'mixtape': True, 'offer': True, 'suckmejimin': True, 'talk': True},
#   'Negative'),
#  ({'10': True,
#    ':)': True,
#    'annoy': True,
#    'follower': True,
#    'group': True,
#    'part': True,
#    'please': True,
#    'side': True,
#    'twitter': True},
#   'Positive'),
#  ({':)': True, 'access': True, 'liam': True}, 'Positive'),
#  ...]

# %%
# NaiveBayes Classifier model

from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy: 0.996
# Most Informative Features
#                       :( = True           Negati : Positi =   2367.2 : 1.0
#                       :) = True           Positi : Negati =   1132.2 : 1.0
#                 follower = True           Positi : Negati =     24.5 : 1.0
#                      bam = True           Positi : Negati =     23.5 : 1.0
#                      sad = True           Negati : Positi =     21.6 : 1.0
#                   arrive = True           Positi : Negati =     21.3 : 1.0
#                      x15 = True           Negati : Positi =     18.4 : 1.0
#                       aw = True           Negati : Positi =     17.8 : 1.0
#                community = True           Positi : Negati =     17.6 : 1.0
#               appreciate = True           Positi : Negati =     15.6 : 1.0
# None

# %%
# Saving model

import pickle

filename = 'finalized_model.sav'
pickle.dump(classifier, open(filename, 'wb'))
